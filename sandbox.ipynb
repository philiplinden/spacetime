# %%
from clocss.model import ClocssModel


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# static example
num_actors = 2
sim = ClocssModel(num_actors, epoch='2023-01-01 00:00:00 UTC', delta_t=1)
for i in range(10):
    sim.step()
# Out:
# mod       DEBUG: Loaded XB in 13 ms.
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau saturn
# cosm      DEBUG: Loaded frame iau earth
# cosm      DEBUG: Loaded frame iau mars
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau moon
# mod       DEBUG: Loaded XB in 16 ms.
# cosm      DEBUG: Loaded frame iau mars
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau earth
# cosm      DEBUG: Loaded frame iau saturn
# mod       DEBUG: Loaded XB in 13 ms.
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau saturn
# ...

# %%
# interactive example
# !mesa runserver
# Out:
# __init__    DEBUG: matplotlib data path: /home/phil/repos/philiplinden/clocss-abm/.venv/lib/python3.11/site-packages/matplotlib/mpl-data
# __init__    DEBUG: CONFIGDIR=/home/phil/.config/matplotlib
# __init__    DEBUG: interactive is False
# __init__    DEBUG: platform is linux
# __init__    DEBUG: CACHEDIR=/home/phil/.cache/matplotlib
# font_manager    DEBUG: Using fontManager instance from /home/phil/.cache/matplotlib/fontlist-v330.json
# mod       DEBUG: Loaded XB in 14 ms.
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau earth
# cosm      DEBUG: Loaded frame iau mars
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau saturn
# mod       DEBUG: Loaded XB in 11 ms.
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau moon
# ...
