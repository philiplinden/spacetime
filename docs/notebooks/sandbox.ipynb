# %%
from clocss.model import OrbitsModel


# %load_ext autoreload
# %autoreload 2

# %%
# static example
num_actors = 2
sim = OrbitsModel(num_actors, epoch='2023-01-01 00:00:00 UTC', delta_t=1)
for i in range(10):
    sim.step()
# Out:
# mod       DEBUG: Loaded XB in 14 ms.
# cosm      DEBUG: Loaded frame iau mars
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau saturn
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau earth
# mod       DEBUG: Loaded XB in 14 ms.
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau saturn
# cosm      DEBUG: Loaded frame iau mars
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau earth
# mod       DEBUG: Loaded XB in 15 ms.
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau earth
# ...

# %%
# interactive example
# !mesa runserver
# Out:
# mod       DEBUG: Loaded XB in 11 ms.
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau saturn
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau mars
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau earth
# mod       DEBUG: Loaded XB in 10 ms.
# cosm      DEBUG: Loaded frame iau jupiter
# cosm      DEBUG: Loaded frame iau saturn
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau sun
# cosm      DEBUG: Loaded frame iau venus
# cosm      DEBUG: Loaded frame iau neptune
# cosm      DEBUG: Loaded frame iau moon
# cosm      DEBUG: Loaded frame iau earth
# cosm      DEBUG: Loaded frame iau mars
# mod       DEBUG: Loaded XB in 7 ms.
# cosm      DEBUG: Loaded frame iau uranus
# cosm      DEBUG: Loaded frame iau mars
# ...
